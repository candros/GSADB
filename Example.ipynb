# %%
'''
Example Notebook for running the Wetlands Detection AI model

Prerequisites & Data Prep
Imagery Format: This notebook expects GeoTIFFs.

Bands: The model expects an 6-band input: red, green, blue, NIR, SWIR1 and SWIR2 Sentinel-2 bands (B2, B3, B4, B8, B11, B12).

Bit Depth: The normalization currently assumes unprocessed 16-bit integer values (0-10000).

Hardware: Large images are processed using a sliding window. A GPU is highly recommended for faster inference.
'''
import os
import numpy as np
import rasterio
from rasterio.windows import Window
import tensorflow as tf
from model.seg_model.resunet32 import ResUNet34

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

# =======================
# 1. Load SwampEye Model
# =======================
def load_swampeye_model(model_path):
    model = ResUNet34()
    model.load_weights(model_path)
    return model

# =======================
# 2. Infer on Patches
# =======================
def infer_patches(patch_list, model):
    predictions = []
    for patch in patch_list:
        patch = patch.transpose(1, 2, 0)  # (H, W, C)

        # Normalize: Assuming 16-bit input (0-10000). Adjust if using 8-bit (0-255).
        patch = np.float32(np.clip(patch / 10000, 0, 1))
        pred = np.squeeze(model(patch[np.newaxis, :]), axis=0)  # (H, W, C)
        predictions.append(np.moveaxis(pred, -1, 0))  # (C, H, W)
    return predictions

# =======================
# 3. Extract Patches
# =======================
def extract_patches(img_path, patch_size=512, min_overlap=0.75):
    with rasterio.open(img_path) as src:
        height, width = src.height, src.width
        stride = int(patch_size * (1 - min_overlap))

        patches = []
        positions = []
        for y in range(0, height - patch_size + 1, stride):
            for x in range(0, width - patch_size + 1, stride):
                window = Window(x, y, patch_size, patch_size)
                patch = src.read(window=window)  # (Bands, H, W)
                patches.append(patch)
                positions.append((x, y))
    return patches, positions, (height, width)

# =======================
# 4. Assemble Mosaic
# =======================
def assemble_mosaic(predictions, positions, shape, threshold=0.5, patch_size=512, return_prob=False):
    num_classes = predictions[0].shape[0]
    H, W = shape
    acc = np.zeros((num_classes, H, W), dtype=np.float32)
    weight = np.zeros((H, W), dtype=np.float32)

    for pred, (x, y) in zip(predictions, positions):
        acc[:, y:y+patch_size, x:x+patch_size] += pred
        weight[y:y+patch_size, x:x+patch_size] += 1

    weight = np.clip(weight, 1e-6, None)
    mosaic = acc / weight[np.newaxis, :, :]

    if return_prob:
        # If only 1 channel, it’s already swamp probability
        prob_map = mosaic[0, :, :] if num_classes == 1 else mosaic[1, :, :]
        return prob_map.astype(np.float32)
    else:
        mask = (mosaic[0, :, :] if num_classes == 1 else mosaic[1, :, :]) > threshold
        return mask.astype(np.uint8)

        
# =======================
# 5. Save Output
# =======================
def save_output(ref_path, output_path, mosaic, return_prob=False, with_colormap=True):
    with rasterio.open(ref_path) as src:
        meta = src.meta.copy()

        if return_prob:
            # Save probability raster (float32, 0–1)
            meta.update({"count": 1, "dtype": "float32", "compress": "lzw"})
            with rasterio.open(output_path, "w", **meta) as dst:
                dst.write(mosaic.astype(np.float32), 1)
            print(f"Saved probability raster to {output_path}")

            # Optional: colorized visualization
            if with_colormap:
                vis_path = output_path.replace(".tif", "_colormap.tif")
                meta.update({"dtype": "uint8"})
                prob_uint8 = np.nan_to_num(mosaic, nan=0.0)  # clean NaNs
                prob_uint8 = (prob_uint8 * 255).clip(0, 255).astype(np.uint8)

                colormap = {i: (
                    int(100 + (123 - 100) * (i / 255)),  # R
                    int(65  + (245 - 65)  * (i / 255)),  # G
                    int(23  + (39  - 23)  * (i / 255)),  # B
                    255
                ) for i in range(256)}

                with rasterio.open(vis_path, "w", **meta) as dst:
                    dst.write(prob_uint8, 1)
                    dst.write_colormap(1, colormap)
                #print(f"Saved colorized probability raster to {vis_path}")

        else:
            # Save binary swamp mask (uint8)
            meta.update({"count": 1, "dtype": "uint8", "compress": "lzw"})
            colormap = {
                0: (100, 65, 23, 255),   # Brown (non-swamp)
                1: (123, 245, 39, 255),  # Green (swamp)
            }
            with rasterio.open(output_path, "w", **meta) as dst:
                dst.write(mosaic, 1)
                dst.write_colormap(1, colormap)
            print(f"Saved binary mask to {output_path}")


# =======================
# 6. Main Driver
# =======================
def run_swampeye_segmentation(
    input_dir,
    swamp_model_path,
    output_dir,
    patch_size=512,
    min_overlap=0.75,
    threshold=0.5,
    return_prob = False
):
    os.makedirs(output_dir, exist_ok=True)
    model = load_swampeye_model(swamp_model_path)

    for filename in os.listdir(input_dir):
        if not filename.lower().endswith((".tif", ".tiff")):
            continue

        print(f"Processing: {filename}")
        input_path = os.path.join(input_dir, filename)

        # Step 1: Extract patches
        patches, positions, img_shape = extract_patches(input_path, patch_size, min_overlap)

        # Step 2: Inference
        preds = infer_patches(patches, model)

        # Step 3: Assemble binary swamp mask
        swamp_mask = assemble_mosaic(preds, positions, img_shape, threshold, patch_size, return_prob)

        # Step 4: Save
        output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_swamp.tif")
        save_output(input_path, output_path, swamp_mask, return_prob)

run_swampeye_segmentation(
    input_dir='',
    swamp_model_path='model/pretrained/resunet_focal_dice.h5py',
    output_dir='',
    threshold = 0.5,
    return_prob = True
)
# Out:
# Processing: Jamaicabay_01_2_2024.tif
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\1\ipykernel_17920\57903310.py in ?()
# --> 154 import os
#     155 import numpy as np
#     156 import rasterio
#     157 from rasterio.windows import Window
#
# ~\AppData\Local\Temp\1\ipykernel_17920\57903310.py in ?(input_dir, swamp_model_path, output_dir, patch_size, min_overlap, threshold, return_prob)
#     141         # Step 1: Extract patches
#     142         patches, positions, img_shape = extract_patches(input_path, patch_size, min_overlap)
#     143
#     144         # Step 2: Inference
# --> 145         preds = infer_patches(patches, model)
#     146
#     147         # Step 3: Assemble binary swamp mask
#     148         swamp_mask = assemble_mosaic(preds, positions, img_shape, threshold, patch_size, return_prob)
#
# ~\AppData\Local\Temp\1\ipykernel_17920\57903310.py in ?(patch_list, model)
#      22         patch = patch.transpose(1, 2, 0)  # (H, W, C)
#      23
#      24         # Normalize: Assuming 16-bit input (0-10000). Adjust if using 8-bit (0-255).
#      25         patch = np.float32(np.clip(patch / 10000, 0, 1))
# ---> 26         pred = np.squeeze(model(patch[np.newaxis, :]), axis=0)  # (H, W, C)
#      27         predictions.append(np.moveaxis(pred, -1, 0))  # (C, H, W)
#      28     return predictions
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py in ?(self, *args, **kwargs)
#     553                 super().__call__(inputs, *copied_args, **copied_kwargs)
#     554
#     555             layout_map_lib._map_subclass_model_variable(self, self._layout_map)
#     556
# --> 557         return super().__call__(*args, **kwargs)
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\engine\base_layer.py in ?(self, *args, **kwargs)
#    1104                     )
#    1105                 if self._saved_model_inputs_spec is None:
#    1106                     self._set_save_spec(inputs, args, kwargs)
#    1107
# -> 1108                 return outputs
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py in ?(self, inputs, training, mask)
#     506         Returns:
#     507             A tensor if there is a single output, or
#     508             a list of tensors if there are more than one outputs.
#     509         """
# --> 510         return self._run_internal_graph(inputs, training=training, mask=mask)
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\engine\functional.py in ?(self, inputs, training, mask)
#     663                 if any(t_id not in tensor_dict for t_id in node.flat_input_ids):
#     664                     continue  # Node is not computable, try skipping.
#     665
#     666                 args, kwargs = node.map_arguments(tensor_dict)
# --> 667                 outputs = node.layer(*args, **kwargs)
#     668
#     669                 # Update tensor_dict.
#     670                 for x_id, y in zip(
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
#      70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
# ---> 72             del filtered_tb
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\engine\base_layer.py in ?(self, *args, **kwargs)
#    1104                     )
#    1105                 if self._saved_model_inputs_spec is None:
#    1106                     self._set_save_spec(inputs, args, kwargs)
#    1107
# -> 1108                 return outputs
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py in ?(*args, **kwargs)
#     154                 new_e = e
#     155             raise new_e.with_traceback(e.__traceback__) from None
#     156         finally:
#     157             del signature
# --> 158             del bound_signature
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\layers\convolutional\base_conv.py in ?(self, inputs)
#     279             outputs = self._jit_compiled_convolution_op(
#     280                 inputs, tf.convert_to_tensor(self.kernel)
#     281             )
#     282         else:
# --> 283             outputs = self.convolution_op(inputs, self.kernel)
#     284
#     285         if self.use_bias:
#     286             output_rank = outputs.shape.rank
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\keras\layers\convolutional\base_conv.py in ?(self, inputs, kernel)
#     251             tf_padding = self.padding.upper()
#     252         else:
#     253             tf_padding = self.padding
#     254
# --> 255         return tf.nn.convolution(
#     256             inputs,
#     257             kernel,
#     258             strides=list(self.strides),
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1180         result = dispatch(op_dispatch_handler, args, kwargs)
#    1181         if result is not OpDispatcher.NOT_SUPPORTED:
#    1182           return result
#    1183         else:
# -> 1184           raise
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(input, filters, strides, padding, data_format, dilations, name)
#    1177     padding="VALID",
#    1178     data_format=None,
#    1179     dilations=None,
#    1180     name=None):
# -> 1181   return convolution_internal(
#    1182       input,  # pylint: disable=redefined-builtin
#    1183       filters,
#    1184       strides=strides,
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(input, filters, strides, padding, data_format, dilations, name, call_from_convolution, num_spatial_dims)
#    1334           dilation_rate=dilations,
#    1335           name=name,
#    1336           data_format=data_format,
#    1337           num_spatial_dims=num_spatial_dims)
# -> 1338       return op(input, filters)
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(input, filters, strides, padding, data_format, dilations, name)
#    2783   input_rank = input.shape.rank
#    2784   if input_rank is None or input_rank < 5:
#    2785     # We avoid calling squeeze_batch_dims to reduce extra python function
#    2786     # call slowdown in eager mode.  This branch doesn't require reshapes.
# -> 2787     return gen_nn_ops.conv2d(
#    2788         input,
#    2789         filter=filters,
#    2790         strides=strides,
#
# ~\AppData\Local\anaconda3\envs\tf\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in ?(input, filter, strides, padding, use_cudnn_on_gpu, explicit_paddings, data_format, dilations, name)
#    1105       return _result
#    1106     except _core._NotOkStatusException as e:
#    1107       _ops.raise_from_not_ok_status(e, name)
#    1108     except _core._FallbackException:
# -> 1109       pass
#    1110     try:
#    1111       return conv2d_eager_fallback(
#    1112           input, filter, strides=strides, use_cudnn_on_gpu=use_cudnn_on_gpu,
#
# KeyboardInterrupt:
